# %%
import pandas as pd
import seaborn as sns
import json

# %%
with open('descriptive_louvain_comm.txt', 'r') as file:
    data_load = json.loads(file.read())
    louvain_df = pd.DataFrame.from_dict(data=data_load, orient='index', columns=['Nodes', 'Average_degree', 'Freeman', 'Average_clustering'])

# %%
louvain_df
# Out:
#     Nodes  Average_degree   Freeman  Average_clustering
# 8    7735       32.700711  0.276681            0.737838
# 4    7560       38.692063  0.289441            0.721430
# 1    5870       36.995230  0.444691            0.747795
# 0    5564       30.459741  0.553055            0.743077
# 3    4336       14.326107  0.389262            0.679135
# 6    2822      135.501063  0.474104            0.718021
# 7    1481       12.887238  0.604271            0.730885
# 5    1218       21.931034  0.343266            0.764629
# 15   1045       17.226794  0.114945            0.753778
# 9    1015        9.812808  0.365797            0.750014

# %%
with open('descriptive_CNM_comm.txt', 'r') as file:
    data_load = json.loads(file.read())
    CNM_df = pd.DataFrame.from_dict(data=data_load, orient='index', columns=['Nodes','Average_degree', 'Freeman', 'Average_clustering'])

# %%
CNM_df
# Out:
#    Nodes  Average_degree   Freeman  Average_clustering
# 0   1347       26.512249  0.213904            0.736925
# 1  11907       33.594860  0.172917            0.703565
# 5  12179       94.581164  0.390721            0.758117
# 6  11720       30.356826  0.212396            0.712799
# 7   1359       12.571008  0.237779            0.769371
# 8   1274       18.770801  0.096954            0.759432
